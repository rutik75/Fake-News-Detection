# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
import pandas as pd

# Load the Fake CSV data
fake = pd.read_csv('Fake.csv')

# Load the True CSV data
true = pd.read_csv('True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class']=0
true['class']=1

# %%
data = pd.concat([fake,true], axis = 0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 632     Elderly California Man Just Savaged A GOP Con...
# 5294    WATCH: Obama CRUSHES Trump With Two Words In ...
# 17104  [VIDEO] FLASHBACK TO THE LIE ABOUT THE VIDEO O...
# 21156  U.S.-led coalition says still monitoring IS co...
# 18863  Avocet's convoy in Burkina Faso strikes landmi...
# 9245         Trump lawyers channel Obama in court filing
# 4852    FBI Finds Evidence That Foreign Hackers Infil...
# 3216   U.S. weighs sanctions on countries doing busin...
# 12808  Peru's Kuczynski says graft probe went too far...
# 12658  ANTI-HILLARY POSTERS POP UP All Over Hollywood...
#
#                                                     text          subject  \
# 632    Republican Rep. Doug LaMalfa (CA) did not have...             News
# 5294   President Barack Obama brought down the house ...             News
# 17104  #NeverForget Sean Smith, Tyrone Woods, Chris D...  Government News
# 21156  BEIRUT (Reuters) - A convoy of Islamic State f...        worldnews
# 18863  OUAGADOUGOU (Reuters) - Two paramilitary polic...        worldnews
# 9245   NEW YORK (Reuters) - When lawyers for Donald T...     politicsNews
# 4852   Another day, another foreign hack into America...             News
# 3216   WASHINGTON (Reuters) - The United States is we...     politicsNews
# 12808  LIMA (Reuters) - Peruvian President Pedro Pabl...        worldnews
# 12658   The first time I heard Negan ask for  50 perc...         politics
#
#                       date  class
# 632         August 8, 2017      0
# 5294         July 28, 2016      0
# 17104         Sep 11, 2015      0
# 21156   September 1, 2017       1
# 18863  September 27, 2017       1
# 9245         June 8, 2016       1
# 4852       August 29, 2016      0
# 3216        June 13, 2017       1
# 12808    December 7, 2017       1
# 12658         Oct 22, 2016      0

# %%
data = data.drop(["title", "subject", "date"], axis = 1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'], axis = 1, inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 28898  WASHINGTON/BERLIN (Reuters) - U.S. Vice Presid...      1
# 33850  BRUSSELS (Reuters) - Europe’s emerging migrati...      1
# 2098   If you haven t heard, the Trump administration...      0
# 35349  BRUSSELS (Reuters) - Austria s new chancellor ...      1
# 37147  MOSCOW (Reuters) - A colleague of Katerina Tik...      1

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]',"", text)
    text = re.sub("\\W"," ",text)
    text = re.sub("https?:://\S+/www\.\S+","", text)
    text = re.sub("<.*?>+","", text)
    text = re.sub("[%s]" % re.escape(string.punctuation),"", text)
    text = re.sub("\n", "", text)
    text = re.sub("\w*\d\w*","", text)
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\wakch\AppData\Local\Temp\ipykernel_5004\2594068591.py:3: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]',"", text)
# C:\Users\wakch\AppData\Local\Temp\ipykernel_5004\2594068591.py:5: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub("https?:://\S+/www\.\S+","", text)
# C:\Users\wakch\AppData\Local\Temp\ipykernel_5004\2594068591.py:9: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub("\w*\d\w*","", text)

# %%
data["text"] = data["text"].apply(clean_text)

# %%
x=data["text"]
y=data["class"]
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=42)
